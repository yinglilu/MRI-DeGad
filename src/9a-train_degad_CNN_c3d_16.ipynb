# %%
import monai
import shutil
from monai.transforms import (
    Compose,
    LoadImaged,
    RandCropByPosNegLabeld,
    Spacingd,
    RandWeightedCrop,
    RandRotate,
    RandFlip,
    Rand3DElasticd,
    Rand3DElastic,
    RandRotated,
    LoadImage,
    EnsureChannelFirstd,
    Orientationd,
    EnsureChannelFirst,
    ScaleIntensityd,
    RandFlip,
    ToTensor,
    SpatialPadd,
    ToTensord,
    ScaleIntensity,
    RandFlipd)
import nibabel
import shutil
import tqdm
from torchmetrics import MeanSquaredError
import time
from monai.networks.nets import UNet
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, Dataset ,nifti_saver, PatchDataset, PersistentDataset, SmartCacheDataset, ThreadDataLoader
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import nibabel
from glob import glob
from monai.networks.blocks import Convolution
from monai.networks.nets import Discriminator, Generator
from monai.utils import progress_bar
import torch.nn as nn
import torchmetrics 
from pytorchtools import EarlyStopping
import numpy 
import torchvision.transforms as transforms
import random
from functools import reduce
from operator import mul
from torch.utils.data import DataLoader

from torchmetrics import StructuralSimilarityIndexMeasure as SSIM

# %%
date="July19"#  put current date if training, test if just testing

if not os.path.exists(f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}'):
    os.makedirs(f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}')
    
if date != "test":
    shutil.copy('/home/fogunsan/scratch/degad/repo/MRI-DeGad/src/9a-train_degad_CNN_c3d_16.py', f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/')

# %%
fname_tr='/localscratch/tmp/training_samples_15.dat'
                        # Patch dimensions

patch_radius= numpy.array([7,7,7])
dims = 1+2*patch_radius 
dims = dims.astype('int')

k = 2                                 # Number of channels
bps = (4 * k * numpy.prod(dims))    # Bytes per sample
np_tr = os.path.getsize(fname_tr) // bps      # Number of samples

arr_shape_tr= (int(np_tr),dims[0],dims[1],dims[2], k)

arr_train = numpy.memmap(fname_tr,'float32','r+',shape=arr_shape_tr)
#arr_train = numpy.swapaxes(arr_train,1,4)
"""
fig, axes = plt.subplots(8, 2,figsize=(5,15))
plt.suptitle('Whole brain slices: Gad, NonGad, Degad')

for i in range (1,17,2):    
    x = random.randint(1,14)
    y = random.randint(1,2000)
    z = random.randint(40, 190)
    plt.subplot(8, 2, i)
    plt.imshow(numpy.squeeze(arr_train[y,x, :,:,0]) ,cmap="gray")
    plt.subplot(8,2 ,i+1)
    plt.imshow(numpy.squeeze(arr_train[y,x, :,:,1]) ,cmap="gray")

"""
# Out:
# '\nfig, axes = plt.subplots(8, 2,figsize=(5,15))\nplt.suptitle(\'Whole brain slices: Gad, NonGad, Degad\')\n\nfor i in range (1,17,2):    \n    x = random.randint(1,14)\n    y = random.randint(1,2000)\n    z = random.randint(40, 190)\n    plt.subplot(8, 2, i)\n    plt.imshow(numpy.squeeze(arr_train[y,x, :,:,0]) ,cmap="gray")\n    plt.subplot(8,2 ,i+1)\n    plt.imshow(numpy.squeeze(arr_train[y,x, :,:,1]) ,cmap="gray")\n\n'

# %%
fname_va='/localscratch/tmp/validation_samples_15.dat'
                        # Patch dimensions

np_va = os.path.getsize(fname_va) // bps      # Number of samples

arr_shape_va= (int(np_va),dims[0],dims[1],dims[2], k)

arr_val= numpy.memmap(fname_va,'float32','r+',shape=arr_shape_va)
#arr_train = numpy.swapaxes(arr_train,1,4)
"""
fig, axes = plt.subplots(8, 2,figsize=(5,15))
plt.suptitle('Whole brain slices: Gad, NonGad, Degad')

for i in range (1,17,2):    
    x = random.randint(1,14)
    y = random.randint(1,2000)
    z = random.randint(40, 190)
    plt.subplot(8, 2, i)
    plt.imshow(numpy.squeeze(arr_val[y,x, :,:,0]) ,cmap="gray")
    plt.subplot(8,2 ,i+1)
    plt.imshow(numpy.squeeze(arr_val[y,x, :,:,1]) ,cmap="gray")
"""
# Out:
# '\nfig, axes = plt.subplots(8, 2,figsize=(5,15))\nplt.suptitle(\'Whole brain slices: Gad, NonGad, Degad\')\n\nfor i in range (1,17,2):    \n    x = random.randint(1,14)\n    y = random.randint(1,2000)\n    z = random.randint(40, 190)\n    plt.subplot(8, 2, i)\n    plt.imshow(numpy.squeeze(arr_val[y,x, :,:,0]) ,cmap="gray")\n    plt.subplot(8,2 ,i+1)\n    plt.imshow(numpy.squeeze(arr_val[y,x, :,:,1]) ,cmap="gray")\n'

# %%
"""
arr_train = numpy.swapaxes(arr_train,1,4)
arr_val = numpy.swapaxes(arr_val,1,4)

arr_train_image = arr_train[:,0,:,:,:].reshape(arr_train.shape[0],1,arr_train.shape[2],arr_train.shape[3],arr_train.shape[4])
arr_train_label = arr_train[:,1,:,:,:].reshape(arr_train.shape[0],1,arr_train.shape[2],arr_train.shape[3],arr_train.shape[4])

arr_val_image = arr_val[:,0,:,:,:].reshape(arr_val.shape[0],1, arr_val.shape[2],arr_val.shape[3],arr_val.shape[4])
arr_val_label = arr_val[:,1,:,:,:].reshape(arr_val.shape[0],1, arr_val.shape[2],arr_val.shape[3],arr_val.shape[4])
"""

# %%
arr_train = numpy.swapaxes(arr_train,1,4)
arr_val = numpy.swapaxes(arr_val,1,4)
train_size=arr_train.shape[0]*0.75
#train_size=int(arr_train.shape[0])

val_size=arr_val.shape[0]*0.75
#val_size=int(arr_val.shape[0]) # reduced size to accelerate training
arr_train_image = arr_train[0:train_size,0,:,:,:].reshape(train_size,1,arr_train.shape[2],arr_train.shape[3],arr_train.shape[4])
arr_train_label = arr_train[0:train_size,1,:,:,:].reshape(train_size,1,arr_train.shape[2],arr_train.shape[3],arr_train.shape[4])

arr_val_image = arr_val[0:val_size,0,:,:,:].reshape(val_size,1, arr_val.shape[2],arr_val.shape[3],arr_val.shape[4])
arr_val_label = arr_val[0:val_size,1,:,:,:].reshape(val_size,1, arr_val.shape[2],arr_val.shape[3],arr_val.shape[4])

# %%
"""
max_mem_req_tr = os.path.getsize(fname_tr)/(10**9) 
max_mem_req_va = os.path.getsize(fname_va) /(10**9)
print(max_mem_req_tr+max_mem_req_va) # ram we would need to cache everything to request is 128
#with 32 gb requested (1/4) timed out at 81889 patches
(4 * k * reduce(mul, dims, 1))*81889 /(10**9) # 19 gigs"""

# %%
arr_train_dict= [{"image": gad_name, "label": nongad_name} for gad_name, nongad_name in zip(arr_train_image,arr_train_label)]
arr_val_dict= [{"image": gad_name, "label": nongad_name} for gad_name, nongad_name in zip(arr_val_image,arr_val_label)]

# %%
train_transforms = Compose([SpatialPadd(keys = ("image","label"), spatial_size = (16,16,16)), Rand3DElasticd(keys = ("image","label"), sigma_range = (0.5,1), magnitude_range = (0.1, 0.4), prob=0.4, shear_range=(0.1, -0.05, 0.0, 0.0, 0.0, 0.0), scale_range=0.5, padding_mode= "zeros"),
          RandFlipd(keys = ("image","label"), prob = 0.5, spatial_axis=1),RandFlipd(keys = ("image","label"), prob = 0.5, spatial_axis=0),RandFlipd(keys = ("image","label"), prob = 0.5, spatial_axis=2)])
val_transforms = Compose([SpatialPadd(keys = ("image","label"),spatial_size = (16,16,16))])

# %%
train_patches_dataset = CacheDataset(data=arr_train_dict ,transform = train_transforms, cache_rate =1.0,num_workers=32, copy_cache=False, progress=True) # dataset with cache mechanism that can load data and cache deterministic transforms’ result during training.
validate_patches_dataset = CacheDataset(data=arr_val_dict ,transform = val_transforms, cache_rate = 1.0, num_workers=32, copy_cache=False,progress=True)
# Out:
# Loading dataset: 100%|██████████| 20000/20000 [00:51<00:00, 390.26it/s]
# Loading dataset: 100%|██████████| 10000/10000 [00:25<00:00, 386.48it/s]

# %%
CNN=UNet(
            spatial_dims=3,
            in_channels=1,
            out_channels=1,
            channels=(32,64,128,256,512,512,512),
            strides=(2, 2, 2,1,1,1),
            dropout= 0.2,
            norm = 'BATCH'
        )

device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # PyTorch v0.4.0
CNN.apply(monai.networks.normal_init) #  initialize the weights of convolutional layers with a normal distribution
CNN_model = CNN.to(device)

# %%
batch_size = 512
training_steps = int(np_tr / batch_size) # number of training steps per epoch
validation_steps = int(np_va / batch_size) # number of validation steps per epoch

# %%
train_loader = DataLoader(train_patches_dataset, batch_size=batch_size, shuffle=False, num_workers=32)
val_loader = DataLoader(validate_patches_dataset, batch_size=batch_size, shuffle=False,num_workers=32)

# %%
import time
learning_rate = 2e-5 # changed from 2e-4
betas = (0.5, 0.999)
cnn_opt = torch.optim.Adam(CNN_model.parameters(), lr = learning_rate, betas=betas)
patience = 40# epochs it will take for training to terminate if no improvement
early_stopping = EarlyStopping(patience=patience, verbose=True, path = f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/checkpoint.pt')
start = time.time() # initializing variable to calculate training time

max_epochs = 1000 # max total iterations over entire training set
#root_mean_squared = MeanSquaredError(squared = False).to(device) #rmse metric calculated at the end of each epoch for training and val
mean_abs_error = torch.nn.L1Loss().to(device)
#SSIM_L = SSIM(gaussian_kernel=True, sigma=1.5, reduction='elementwise_mean').to(device)

mae_val = [0] # list of validation loss calculated at the end of each epoch
epoch_loss_values = [0] # list of training loss calculated at the end of each epoch

#train_loader = DataLoader(train_patches_dataset, batch_size=batch_size, shuffle=True, num_workers = 16)
#val_loader = DataLoader(validate_patches_dataset, batch_size=batch_size, shuffle=True, num_workers =16)

for epoch in range(max_epochs):
    CNN_model.train() # setting model to training mode
    epoch_loss = 0 # total traininig loss in an epoch
    progress_bar(
            index=epoch+1, # displays what step we are of current epoch, our epoch number, training  loss
            count = max_epochs, 
            desc= f"epoch {epoch + 1}, training mae loss: {epoch_loss_values[-1]:.4f}, validation mae metric: {mae_val[-1]:.4f}",
            newline = True) # progress bar to display current stage in training
   
    for i,train_batch in enumerate(train_loader): # iterating through dataloader
        gad_images =train_batch["image"].cuda()# batch with gad images
        nongad_images = train_batch["label"].cuda() # batch with nongad images
        #plt.subplot(2, 1, 1)
        #plt.imshow(gad_images[0, 0,: ,:, 20].cpu().data.numpy(), cmap ="gray")
        #plt.subplot(2, 1, 2)
        cnn_opt.zero_grad()
        degad_images = CNN_model(gad_images) # feeding CNN with gad images
        #MAE_loss = mean_abs_error(degad_images, nongad_images)
        #SSIM_loss = 1- SSIM_L(degad_images, nongad_images) # want to maximize SSIM loss so subtract from 1
        #train_loss= 0.5*MAE_loss + 0.35*SSIM_loss
        train_loss = mean_abs_error(degad_images, nongad_images)
        print(train_loss)
        train_loss.backward()
        cnn_opt.step()
        epoch_loss += train_loss.item() # adding loss for this batch to the total training loss for this epoch
    avg_training_loss = epoch_loss / training_steps
    epoch_loss_values.append(avg_training_loss) # append total epoch loss divided by the number of training steps in epoch to loss list
    CNN_model.eval() #setting model to evaluation mode for validation
    with torch.no_grad(): #we do not update weights/biases in validation training, only used to assess current state of model
        mae_total_epoch = 0 # mean absolute error for the entire epoch
        for i,val_batch in enumerate(val_loader): # iterating through dataloader
            gad_images =val_batch["image"].cuda()# batch with gad images
            nongad_images = val_batch["label"].cuda() # batch with nongad images
            degad_images = CNN_model(gad_images)
            #MAE_loss = mean_abs_error(degad_images, nongad_images)
            #SSIM_loss = 1- SSIM_L(degad_images, nongad_images)
            #val_loss= 0.5*MAE_loss + 0.35*SSIM_loss
            val_loss = mean_abs_error(degad_images, nongad_images)
            mae_total_epoch += val_loss # adding val mse of this batch to total val epoch mse
        avg_val_mae = mae_total_epoch.item()/validation_steps
        mae_val.append(avg_val_mae) # dividing total mse in this epoch by the number of batches -> add to list of epoch mse
        early_stopping(avg_val_mae, CNN_model) # early stopping is based on the average validation mse for an epoch, keeps track of last best model
        
    if early_stopping.early_stop:
        print("Early stopping") # stops early if validation mae has not improved for 100 epochs
        break
    

end = time.time()
time = end - start
print(time)
# Out:
# 1/1000 epoch 1, training mae loss: 0.0000, validation mae metric: 0.0000 [                              ]
# tensor(0.0911, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0868, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0782, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0802, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0904, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0818, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0865, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0855, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0888, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0920, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0996, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0787, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0912, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.1010, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.1023, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0950, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0856, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0898, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0991, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0879, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0877, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0848, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0843, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.1062, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0925, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0760, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0760, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0882, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0748, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0681, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0865, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0858, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0814, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0792, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0860, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0894, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0833, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0774, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0824, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0864, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (inf --> 0.000266).  Saving model ...
# 2/1000 epoch 2, training mae loss: 0.0007, validation mae metric: 0.0003 [                              ]
# tensor(0.0595, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0578, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0518, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0540, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0621, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0564, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0598, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0593, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0613, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0640, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0692, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0552, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0647, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0717, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0729, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0684, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0617, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0650, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0727, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0644, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0655, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0632, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0632, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0815, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0707, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0579, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0580, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0688, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0576, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0529, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0678, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0676, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0642, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0628, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0685, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0719, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0668, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0622, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0669, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0701, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000266 --> 0.000239).  Saving model ...
# 3/1000 epoch 3, training mae loss: 0.0005, validation mae metric: 0.0002 [                              ]
# tensor(0.0483, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0469, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0419, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0440, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0505, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0461, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0487, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0483, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0500, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0521, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0562, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0453, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0528, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0587, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0598, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0562, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0510, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0539, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0607, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0538, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0549, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0532, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0534, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0693, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0599, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0493, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0492, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0588, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0492, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0452, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0578, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0582, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0551, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0541, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0590, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0627, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0578, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0536, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0585, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0607, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000239 --> 0.000222).  Saving model ...
# 4/1000 epoch 4, training mae loss: 0.0004, validation mae metric: 0.0002 [                              ]
# tensor(0.0416, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0407, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0363, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0380, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0440, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0400, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0423, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0421, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0433, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0454, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0489, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0395, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0460, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0512, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0524, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0492, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0445, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0474, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0536, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0473, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0485, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0472, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0473, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0619, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0533, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0438, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0438, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0528, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0439, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0405, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0516, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0522, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0495, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0488, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0532, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0570, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0520, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0482, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0531, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0546, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000222 --> 0.000197).  Saving model ...
# 5/1000 epoch 5, training mae loss: 0.0004, validation mae metric: 0.0002 [                              ]
# tensor(0.0375, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0365, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0325, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0343, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0395, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0359, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0380, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0379, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0389, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0409, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0441, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0355, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0415, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0462, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0472, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0443, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0401, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0427, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0487, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0429, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0439, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0425, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0431, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0566, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0486, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0400, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0398, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0485, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0400, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0372, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0473, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0478, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0455, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0449, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0487, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0527, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0478, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0444, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0491, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0508, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000197 --> 0.000177).  Saving model ...
# 6/1000 epoch 6, training mae loss: 0.0003, validation mae metric: 0.0002 [                              ]
# tensor(0.0343, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0334, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0297, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0313, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0361, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0330, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0349, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0348, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0356, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0374, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0403, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0326, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0381, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0423, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0432, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0407, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0368, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0392, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0450, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0394, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0404, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0393, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0396, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0527, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0450, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0370, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0369, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0452, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0370, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0343, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0438, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0446, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0425, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0419, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0455, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0494, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0445, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0412, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0460, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0470, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000177 --> 0.000162).  Saving model ...
# 7/1000 epoch 7, training mae loss: 0.0003, validation mae metric: 0.0002 [                              ]
# tensor(0.0317, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0290, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0336, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0323, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0323, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0331, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0347, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0374, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0301, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0351, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0393, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0400, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0377, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0339, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0363, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0418, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0367, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0375, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0367, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0369, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0493, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0419, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0346, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0344, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0424, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0345, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0321, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0409, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0418, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0397, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0393, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0426, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0466, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0417, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0387, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0431, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0439, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000162 --> 0.000150).  Saving model ...
# 8/1000 epoch 8, training mae loss: 0.0003, validation mae metric: 0.0001 [                              ]
# tensor(0.0297, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0289, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0258, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0313, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0302, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0310, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0324, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0350, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0281, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0328, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0365, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0371, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0352, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0315, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0338, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0391, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0352, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0346, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0465, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0394, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0325, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0321, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0398, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0323, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0383, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0391, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0374, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0371, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0400, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0441, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0393, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0363, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0410, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0419, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000150 --> 0.000139).  Saving model ...
# 9/1000 epoch 9, training mae loss: 0.0003, validation mae metric: 0.0001 [                              ]
# tensor(0.0280, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0272, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0242, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0253, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0293, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0285, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0285, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0291, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0329, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0343, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0346, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0330, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0294, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0315, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0367, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0320, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0330, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0322, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0324, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0440, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0371, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0306, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0300, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0376, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0304, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0285, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0362, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0371, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0354, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0349, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0379, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0420, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0371, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0389, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0404, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000139 --> 0.000131).  Saving model ...
# 10/1000 epoch 10, training mae loss: 0.0003, validation mae metric: 0.0001 [                              ]
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0258, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0241, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0254, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0277, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0287, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0310, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0290, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0322, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0327, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0298, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0347, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0302, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0312, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0417, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0352, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0291, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0284, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0357, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0288, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0272, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0350, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0337, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0334, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0360, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0402, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0351, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0326, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0372, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0386, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000131 --> 0.000125).  Saving model ...
# 11/1000 epoch 11, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0252, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0247, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0221, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0244, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0273, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0297, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0306, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0308, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0294, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0263, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0282, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0330, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0284, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0297, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0289, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0293, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0400, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0336, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0274, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0260, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0327, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0336, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0322, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0319, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0344, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0385, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0337, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0313, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0357, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0359, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000125 --> 0.000119).  Saving model ...
# 12/1000 epoch 12, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0240, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0233, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0218, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0249, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0228, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0283, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0224, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0261, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0291, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0292, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0277, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0269, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0313, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0282, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0278, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0381, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0320, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0264, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0327, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0261, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0312, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0319, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0330, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0371, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0323, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0297, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0344, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0344, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000119 --> 0.000114).  Saving model ...
# 13/1000 epoch 13, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0231, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0224, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0203, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0241, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0218, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0240, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0215, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0280, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0279, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0301, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0257, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0266, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0367, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0254, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0315, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0239, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0300, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0296, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0295, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0318, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0358, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0311, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0332, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0338, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000114 --> 0.000110).  Saving model ...
# 14/1000 epoch 14, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0196, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0199, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0226, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0233, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0240, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0269, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0245, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0288, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0253, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0257, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0352, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0295, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0244, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0304, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0241, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0288, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0298, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0285, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0284, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0348, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0299, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0277, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0321, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0322, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000110 --> 0.000106).  Saving model ...
# 15/1000 epoch 15, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0214, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0189, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0190, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0221, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0203, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0198, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0229, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0257, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0245, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0218, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0235, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0277, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0237, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0245, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0247, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0286, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0296, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0278, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0288, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0275, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0299, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0338, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0291, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0267, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0313, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0311, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000106 --> 0.000103).  Saving model ...
# 16/1000 epoch 16, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0208, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0198, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0187, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0214, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0212, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0242, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0189, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0221, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0235, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0235, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0331, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0277, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0229, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0221, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0285, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0224, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0215, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0278, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0269, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0269, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0288, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0330, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0280, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0305, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0310, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000103 --> 0.000101).  Saving model ...
# 17/1000 epoch 17, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0200, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0191, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0179, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0188, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0203, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0204, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0181, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0214, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0234, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0226, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0203, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0218, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0260, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0231, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0318, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0268, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0221, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0277, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0262, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0269, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0261, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0281, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0322, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0273, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0296, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0293, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000101 --> 0.000099).  Saving model ...
# 18/1000 epoch 18, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0194, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0182, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0198, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0179, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0194, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0196, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0197, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0175, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0204, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0231, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0220, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0251, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0214, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0309, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0259, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0271, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0203, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0251, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0260, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0256, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0254, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0276, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0314, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0267, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0244, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0290, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0289, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000099 --> 0.000095).  Saving model ...
# 19/1000 epoch 19, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0186, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0173, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0162, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0175, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0186, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0189, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0191, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0199, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0218, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0197, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0224, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0188, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0208, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0216, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0216, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0215, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0303, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0254, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0200, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0200, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0257, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0249, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0266, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0307, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0260, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0236, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0283, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0278, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000095 --> 0.000094).  Saving model ...
# 20/1000 epoch 20, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0180, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0185, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0166, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0182, device='cuda:0', grad_fn=<AliasBackward0>)
# ...
# tensor(0.0137, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0139, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0174, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0174, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0173, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0189, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0148, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0174, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0194, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0187, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0181, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0193, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0274, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0229, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0188, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0182, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0228, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0242, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0281, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0235, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0255, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000087 --> 0.000085).  Saving model ...
# 25/1000 epoch 25, training mae loss: 0.0002, validation mae metric: 0.0001 [                              ]
# tensor(0.0153, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0157, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0162, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0161, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0181, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0172, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0156, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0172, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0183, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0184, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0266, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0220, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0173, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0223, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0216, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0231, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0272, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0227, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0207, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0249, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0242, device='cuda:0', grad_fn=<AliasBackward0>)
# EarlyStopping counter: 1 out of 40
# 26/1000 epoch 26, training mae loss: 0.0001, validation mae metric: 0.0001 [                              ]
# tensor(0.0146, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0148, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0153, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0175, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0152, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0180, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0180, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0258, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0210, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0175, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0226, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0174, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0207, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0220, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0212, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0232, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0270, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0222, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0202, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0249, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0238, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000085 --> 0.000083).  Saving model ...
# 27/1000 epoch 27, training mae loss: 0.0001, validation mae metric: 0.0001 [                              ]
# tensor(0.0143, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0130, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0127, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0128, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0148, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0133, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0142, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0148, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0168, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0125, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0149, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0170, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0147, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0201, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0174, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0178, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0176, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0253, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0162, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0221, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0163, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0201, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0216, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0212, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0209, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0225, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0199, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0243, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0234, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000083 --> 0.000081).  Saving model ...
# 28/1000 epoch 28, training mae loss: 0.0001, validation mae metric: 0.0001 [                              ]
# tensor(0.0138, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0128, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0128, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0129, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0141, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0151, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0122, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0168, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0159, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0159, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0197, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0162, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0172, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0171, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0246, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0167, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0159, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0217, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0162, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0197, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0211, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0204, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0205, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0219, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0257, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0213, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0194, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0235, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0230, device='cuda:0', grad_fn=<AliasBackward0>)
# Validation loss decreased (0.000081 --> 0.000080).  Saving model ...
# 29/1000 epoch 29, training mae loss: 0.0001, validation mae metric: 0.0001 [                              ]
# tensor(0.0132, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0118, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0115, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0140, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0131, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0136, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0141, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0144, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0145, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0157, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0117, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0143, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0161, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0161, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0141, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0192, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0159, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0164, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0169, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0168, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0245, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0199, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0155, device='cuda:0', grad_fn=<AliasBackward0>)
# tensor(0.0214, device='cuda:0', grad_fn=<AliasBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 35
#      31 nongad_images = train_batch["label"].cuda() # batch with nongad images
#      32 #plt.subplot(2, 1, 1)
#      33 #plt.imshow(gad_images[0, 0,: ,:, 20].cpu().data.numpy(), cmap ="gray")
#      34 #plt.subplot(2, 1, 2)
# ---> 35 cnn_opt.zero_grad()
#      36 degad_images = CNN_model(gad_images) # feeding CNN with gad images
#      37 #MAE_loss = mean_abs_error(degad_images, nongad_images)
#      38 #SSIM_loss = 1- SSIM_L(degad_images, nongad_images) # want to maximize SSIM loss so subtract from 1
#      39 #train_loss= 0.5*MAE_loss + 0.35*SSIM_loss
#
# File /local/fogunsan.7644559.0/tmp/kslurm-venv-xm_tacge/lib/python3.10/site-packages/torch/optim/optimizer.py:267, in Optimizer.zero_grad(self, set_to_none)
#     265 if foreach:
#     266     per_device_and_dtype_grads = defaultdict(lambda: defaultdict(list))
# --> 267 with torch.autograd.profiler.record_function(self._zero_grad_profile_name):
#     268     for group in self.param_groups:
#     269         for p in group['params']:
#
# File /local/fogunsan.7644559.0/tmp/kslurm-venv-xm_tacge/lib/python3.10/site-packages/torch/autograd/profiler.py:493, in record_function.__exit__(self, exc_type, exc_value, traceback)
#     491 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any):
#     492     if self.run_callbacks_on_exit:
# --> 493         torch.ops.profiler._record_function_exit(self.handle)
#
# File /local/fogunsan.7644559.0/tmp/kslurm-venv-xm_tacge/lib/python3.10/site-packages/torch/_ops.py:442, in OpOverloadPacket.__call__(self, *args, **kwargs)
#     437 def __call__(self, *args, **kwargs):
#     438     # overloading __call__ to ensure torch.ops.foo.bar()
#     439     # is still callable from JIT
#     440     # We save the function ptr as the `op` attribute on
#     441     # OpOverloadPacket to access it here.
# --> 442     return self._op(*args, **kwargs or {})
#
# KeyboardInterrupt:

# %%
with open (f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/model_stats.txt', 'w') as file:  
    file.write(f'training time: {time}\n')  
    file.write(f'training loss: {epoch_loss_values[-patience]} validation loss: {early_stopping.val_loss_min}')

# %%
plt.figure(figsize=(12,5))
plt.plot(list(range(len(epoch_loss_values))), epoch_loss_values, label="Training Loss")
plt.plot(list(range(len(mae_val))), mae_val , label="Validation Loss")
plt.grid(True, "both", "both")
plt.legend()
plt.savefig(f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/lossfunction.png')

# %%
CNN_model.load_state_dict(torch.load(f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/checkpoint.pt'))
CNN_model.eval()
# Out:
# UNet(
#   (model): Sequential(
#     (0): Convolution(
#       (conv): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#       (adn): ADN(
#         (N): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (D): Dropout(p=0.2, inplace=False)
#         (A): PReLU(num_parameters=1)
#       )
#     )
#     (1): SkipConnection(
#       (submodule): Sequential(
#         (0): Convolution(
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (adn): ADN(
#             (N): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (D): Dropout(p=0.2, inplace=False)
#             (A): PReLU(num_parameters=1)
#           )
#         )
#         (1): SkipConnection(
#           (submodule): Sequential(
#             (0): Convolution(
#               (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (adn): ADN(
#                 (N): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.2, inplace=False)
#                 (A): PReLU(num_parameters=1)
#               )
#             )
#             (1): SkipConnection(
#               (submodule): Sequential(
#                 (0): Convolution(
#                   (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                   (adn): ADN(
#                     (N): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (D): Dropout(p=0.2, inplace=False)
#                     (A): PReLU(num_parameters=1)
#                   )
#                 )
#                 (1): SkipConnection(
#                   (submodule): Sequential(
#                     (0): Convolution(
#                       (conv): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                       (adn): ADN(
#                         (N): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                         (D): Dropout(p=0.2, inplace=False)
#                         (A): PReLU(num_parameters=1)
#                       )
#                     )
#                     (1): SkipConnection(
#                       (submodule): Sequential(
#                         (0): Convolution(
#                           (conv): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                           (adn): ADN(
#                             (N): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                             (D): Dropout(p=0.2, inplace=False)
#                             (A): PReLU(num_parameters=1)
#                           )
#                         )
#                         (1): SkipConnection(
#                           (submodule): Convolution(
#                             (conv): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                             (adn): ADN(
#                               (N): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                               (D): Dropout(p=0.2, inplace=False)
#                               (A): PReLU(num_parameters=1)
#                             )
#                           )
#                         )
#                         (2): Convolution(
#                           (conv): ConvTranspose3d(1024, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                           (adn): ADN(
#                             (N): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                             (D): Dropout(p=0.2, inplace=False)
#                             (A): PReLU(num_parameters=1)
#                           )
#                         )
#                       )
#                     )
#                     (2): Convolution(
#                       (conv): ConvTranspose3d(1024, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                       (adn): ADN(
#                         (N): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                         (D): Dropout(p=0.2, inplace=False)
#                         (A): PReLU(num_parameters=1)
#                       )
#                     )
#                   )
#                 )
#                 (2): Convolution(
#                   (conv): ConvTranspose3d(512, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                   (adn): ADN(
#                     (N): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                     (D): Dropout(p=0.2, inplace=False)
#                     (A): PReLU(num_parameters=1)
#                   )
#                 )
#               )
#             )
#             (2): Convolution(
#               (conv): ConvTranspose3d(256, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#               (adn): ADN(
#                 (N): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.2, inplace=False)
#                 (A): PReLU(num_parameters=1)
#               )
#             )
#           )
#         )
#         (2): Convolution(
#           (conv): ConvTranspose3d(128, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#           (adn): ADN(
#             (N): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (D): Dropout(p=0.2, inplace=False)
#             (A): PReLU(num_parameters=1)
#           )
#         )
#       )
#     )
#     (2): Convolution(
#       (conv): ConvTranspose3d(64, 1, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     )
#   )
# )

# %%
# running inference on only one test subject
test_gad = sorted(glob('/localscratch/tmp/passing_dataset/sub-P*/sub-P*_acq-gad_rescaled_T1w.nii.gz'))[0:2]
test_nongad = sorted(glob('/localscratch/tmp/passing_dataset/sub-P*/sub-P*_acq-nongad_normalized_fcm.nii.gz'))[0:2]
test_dict = [{"image": gad_name, "label": nongad_name} for gad_name, nongad_name in zip(test_gad,test_nongad)] #creates list of dictionaries, with gad and nongad images labelled


inference_transforms = Compose( #loading full image
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"])])
        

infer_ds = Dataset(data=test_dict, transform=inference_transforms) 
infer_loader = DataLoader(infer_ds, batch_size=1, shuffle=True) #using pytorch's dataloader

# %%
degad_imgs = []
gad_infer_imgs = []
nongad_infer_imgs = []
for infer_imgs in infer_loader:
    gad_infer_imgs.append(infer_imgs["image"])
    nongad_infer_imgs.append(infer_imgs["label"])
    output_degad_img = sliding_window_inference(inputs = infer_imgs["image"].to('cpu'), roi_size = (16,16,16), sw_batch_size= 5, predictor = CNN_model.to('cpu'), overlap = 0.25, mode = "gaussian", sw_device= 'cpu', device = 'cpu', progress = True )
    degad_imgs.append(output_degad_img)
# Out:
# 100%|██████████| 1452/1452 [01:23<00:00, 17.34it/s]
# 100%|██████████| 2007/2007 [01:54<00:00, 17.53it/s]

# %%
for i in range(len(degad_imgs)): #looping thru number of output files
    degad_img =degad_imgs[i][0][0] # reshaping to exclude batch and channels (only one channel)
    gad_image= nibabel.load(test_dict[i]["image"]) # getting original gad image back to compare to 
    gad_image_file = test_dict[i]["image"]
    print(gad_image_file)
    sub = os.path.basename(gad_image_file).split("_")[0]
    degad_name = f'{sub}_acq-degad_T1w.nii.gz'
    degad_file = nibabel.Nifti1Image(degad_img.detach().numpy()*100, affine= gad_image.affine,header= gad_image.header) # with same header as inference gad 
    output_dir = f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/test'
    os.makedirs(f'{output_dir}/bids/{sub}/ses-pre/anat', exist_ok=True)# save in bids format
    output_path = f'{output_dir}/bids/{sub}/ses-pre/anat/{degad_name}'
    nibabel.save(degad_file,output_path)
# Out:
# /localscratch/tmp/passing_dataset/sub-P002/sub-P002_acq-gad_rescaled_T1w.nii.gz
# /localscratch/tmp/passing_dataset/sub-P003/sub-P003_acq-gad_rescaled_T1w.nii.gz

# %%
import random
## generating random whole brain slices
fig, axes = plt.subplots(8, 3,figsize=(10,25))
plt.suptitle('Whole brain slices: Gad, NonGad, Degad')

for i in range (1,25,3):
    plt.subplot(8, 3, i)
    x = random.randint(80, 130)
    plt.imshow(gad_infer_imgs[0][0, 0,40:210 ,40:150, x].cpu().data.numpy(), cmap ="gray")
    
    plt.subplot(8, 3, i+1)
    plt.imshow(nongad_infer_imgs[0][0, 0, 40:210 , 40:150, x].cpu().data.numpy(), "gray")
    
    plt.subplot(8, 3, i+2)
    plt.imshow(degad_imgs[0][0, 0, 40:210,40:150, x].cpu().data.numpy(), "gray")

plt.savefig(f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/test/figure_whole_brain.png')

# %%
#generating random 32x32 slices
fig, axes = plt.subplots(8, 4,figsize=(10,20))
plt.suptitle('Whole brain slices: Gad, NonGad, Degad')

for i in range (1,25,3):
    
    x = random.randint(40, 190)
    y = random.randint(40, 190)
    z = random.randint(40, 190)
    plt.subplot(8, 3, i)
    plt.imshow(gad_infer_imgs[0][0, 0, x:x+16,y:y+16 ,50].cpu().data.numpy(), cmap ="gray")
    plt.subplot(8, 3, i+1)
    plt.imshow(nongad_infer_imgs[0][0, 0, x:x+16,y:y+16,50].cpu().data.numpy(), "gray")
    plt.subplot(8, 3, i+2)
    plt.imshow(degad_imgs[0][0, 0, x:x+16,y:y+16,50].cpu().data.numpy(), "gray")
   

plt.savefig(f'/home/fogunsan/scratch/degad/derivatives/UNET/{date}/test/figure_16_patches.png')
# Out:
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
